# %%
import requests
import datetime
import pandas as pd
import binance

# %%
pd.DataFrame([binance.prices().keys()])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-6cc085eea1dd> in <module>()
# ----> 1 pd.DataFrame([binance.prices().keys()])
#
# AttributeError: module 'binance' has no attribute 'prices'

# %%
a = binance.klines(symbol = 'BTCUSDT',interval = '4h')

# %%
datetime.datetime.fromtimestamp(int(str(a[-1]['openTime'])[:10]))
# Out:
# datetime.datetime(2020, 9, 17, 16, 0)

# %%
datetime.datetime.fromtimestamp(a[0]['closeTime'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-6accf93a8c7b> in <module>()
# ----> 1 datetime.datetime.fromtimestamp(a[0]['closeTime'])
#
# ValueError: year 52626 is out of range

# %%
username = 
password =

# %%
session = requests.Session()
session.auth = (username, password)

# %%
api_key = '5swp3Kz1T6XKtUdUy6hQ9pA0b3GA8F19NijnpDb6MkbSBuX38CKjmtdoc64z12EQ'
api_secret = '3DS5rj8WwUuapFtzjYRDMPl3Q6ZqMqQVoyPvKsChGJFJgBDGoQlrDyZw7Mm4Z63Y'

# %%
from binance.client import Client
client = Client(api_key, api_secret)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-23-b988c7d5f7b8> in <module>()
# ----> 1 from binance.client import Client
#       2 client = Client(api_key, api_secret)
#
# ModuleNotFoundError: No module named 'binance.client'; 'binance' is not a package

# %%
binance.allOrders('ETHBTC',)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-79ba63f34f11> in <module>()
# ----> 1 binance.allOrders('ETHBTC')
#
# ~/anaconda3/lib/python3.6/site-packages/binance.py in allOrders(symbol, **kwargs)
#     209     params = {"symbol": symbol}
#     210     params.update(kwargs)
# --> 211     data = signedRequest("GET", "/api/v3/allOrders", params)
#     212     return data
#     213
#
# ~/anaconda3/lib/python3.6/site-packages/binance.py in signedRequest(method, path, params)
#     240 def signedRequest(method, path, params):
#     241     if "apiKey" not in options or "secret" not in options:
# --> 242         raise ValueError("Api key and secret must be set")
#     243
#     244     query = urlencode(sorted(params.items()))
#
# ValueError: Api key and secret must be set

# %%
import binance
import pandas as pd

# %%
binance.

# %%
binance.klines(symbol='BNBBTC', interval='hour')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-1b402f4eaefd> in <module>()
# ----> 1 binance.klines(symbol='BNBBTC', interval='hour')
#
# AttributeError: module 'binance' has no attribute 'klines'

# %%
binance.allOrders(symbol = 'DCR',apiKey = api_key,secret = api_secret)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-d1a2defcf50e> in <module>()
#       1
# ----> 2 binance.allOrders(symbol = 'DCR',apiKey = api_key,secret = api_secret)
#       3
#
# ~/anaconda3/lib/python3.6/site-packages/binance.py in allOrders(symbol, **kwargs)
#     209     params = {"symbol": symbol}
#     210     params.update(kwargs)
# --> 211     data = signedRequest("GET", "/api/v3/allOrders", params)
#     212     return data
#     213
#
# ~/anaconda3/lib/python3.6/site-packages/binance.py in signedRequest(method, path, params)
#     240 def signedRequest(method, path, params):
#     241     if "apiKey" not in options or "secret" not in options:
# --> 242         raise ValueError("Api key and secret must be set")
#     243
#     244     query = urlencode(sorted(params.items()))
#
# ValueError: Api key and secret must be set

# %%
binance.

# %%
binance.time.time()
# Out:
# 1599060359.215065

# %%
import datetime
timestamp = datetime.datetime.fromtimestamp(binance.time.time())
print(timestamp.strftime('%Y-%m-%d %H:%M:%S'))
print(timestamp)
# Out:
# 2020-09-02 10:41:43
# 2020-09-02 10:41:43.187884

# %%
a = binance.tickers()
len(a.keys())
# Out:
# 1004

# %%
import re
re.

# %%
Keys_List = a.keys()

# %%
keys = {}
for x in Keys_List:
    keys[x] = 1

# %%
blanks = []
for x in Keys_List:
    invKey = x[3,6]x[0:3]
# Out:
# {'ETHBTC': 1,
#  'LTCBTC': 1,
#  'BNBBTC': 1,
#  'NEOBTC': 1,
#  'QTUMETH': 1,
#  'EOSETH': 1,
#  'SNTETH': 1,
#  'BNTETH': 1,
#  'BCCBTC': 1,
#  'GASBTC': 1,
#  'BNBETH': 1,
#  'BTCUSDT': 1,
#  'ETHUSDT': 1,
#  'HSRBTC': 1,
#  'OAXETH': 1,
#  'DNTETH': 1,
#  'MCOETH': 1,
#  'ICNETH': 1,
#  'MCOBTC': 1,
#  'WTCBTC': 1,
#  'WTCETH': 1,
#  'LRCBTC': 1,
#  'LRCETH': 1,
#  'QTUMBTC': 1,
#  'YOYOBTC': 1,
#  'OMGBTC': 1,
#  'OMGETH': 1,
#  'ZRXBTC': 1,
#  'ZRXETH': 1,
#  'STRATBTC': 1,
#  'STRATETH': 1,
#  'SNGLSBTC': 1,
#  'SNGLSETH': 1,
#  'BQXBTC': 1,
#  'BQXETH': 1,
#  'KNCBTC': 1,
#  'KNCETH': 1,
#  'FUNBTC': 1,
#  'FUNETH': 1,
#  'SNMBTC': 1,
#  'SNMETH': 1,
#  'NEOETH': 1,
#  'IOTABTC': 1,
#  'IOTAETH': 1,
#  'LINKBTC': 1,
#  'LINKETH': 1,
#  'XVGBTC': 1,
#  'XVGETH': 1,
#  'SALTBTC': 1,
#  'SALTETH': 1,
#  'MDABTC': 1,
#  'MDAETH': 1,
#  'MTLBTC': 1,
#  'MTLETH': 1,
#  'SUBBTC': 1,
#  'SUBETH': 1,
#  'EOSBTC': 1,
#  'SNTBTC': 1,
#  'ETCETH': 1,
#  'ETCBTC': 1,
#  'MTHBTC': 1,
# ...

# %%
aDict = {}

for key in Keys_List:
    try:
        aDict[len(key)] = aDict[len(key)] + 1
    except:
        aDict[len(key)] = 1

print(aDict)
# Out:
# {6: 413, 7: 371, 8: 149, 5: 11, 9: 33, 10: 5, 11: 21, 12: 1}

# %%
lengths = []
for x in aDict.keys():
    lengths.append([x,aDict[x]])

# %%
DF = pd.DataFrame(lengths)
DF.columns = ['Lenghts','Count']

# %%
DF
# Out:
#    Lenghts  Count
# 0        6    413
# 1        7    371
# 2        8    149
# 3        5     11
# 4        9     33
# 5       10      5
# 6       11     21
# 7       12      1

# %%
# Out:
# ERROR:root:Invalid symbol.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-73-820e24754c4a> in <module>()
# ----> 1 binance.klines('ETH',2)
#
# ~/anaconda3/lib/python3.6/site-packages/binance.py in klines(symbol, interval, **kwargs)
#      97         "quoteVolume": d[7],
#      98         "numTrades": d[8],
# ---> 99     } for d in data]
#     100
#     101
#
# ~/anaconda3/lib/python3.6/site-packages/binance.py in <listcomp>(.0)
#      97         "quoteVolume": d[7],
#      98         "numTrades": d[8],
# ---> 99     } for d in data]
#     100
#     101
#
# IndexError: string index out of range

# %%
#Importing Data
global apiURL
global Periods
global platform
global username
global password

apiURL = "https://api.binance.com/api/v3/"

api_key = '5swp3Kz1T6XKtUdUy6hQ9pA0b3GA8F19NijnpDb6MkbSBuX38CKjmtdoc64z12EQ'
api_secret = '3DS5rj8WwUuapFtzjYRDMPl3Q6ZqMqQVoyPvKsChGJFJgBDGoQlrDyZw7Mm4Z63Y'

# %%
session = requests.Session()
session.auth = (api_key, api_secret)

# %%
url = "{}{}".format(apiURL,'hashlib')

request = session.get(url)

# %%
request.content
# Out:
# b'<html><body><h2>404 Not found</h2></body></html>'
